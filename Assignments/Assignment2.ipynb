# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

data = pd.read_csv("titanic.csv")

# %%
#3)univariate analysis
sns.displot(data.age.value_counts())

# %%
#univariate analysis
plt.pie(data.embark_town.value_counts(),colors=['red','blue','orange'],labels=['Southampton','Cherbourg','Queenstown'],autopct='%.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f11473fb760>,
#   <matplotlib.patches.Wedge at 0x7f11473fb670>,
#   <matplotlib.patches.Wedge at 0x7f11472384f0>],
#  [Text(-0.7128398214280038, 0.8377704870586524, 'Southampton'),
#   Text(0.4614522559226597, -0.9985298270476893, 'Cherbourg'),
#   Text(1.0595276168013974, -0.29563698894954155, 'Queenstown')],
#  [Text(-0.38882172077891114, 0.4569657202138104, '72.44%'),
#   Text(0.25170123050326887, -0.5446526329351032, '18.90%'),
#   Text(0.577924154618944, -0.16125653942702264, '8.66%')])

# %%
#univariate analysis
sns.displot(data.fare.value_counts())

# %%
#univariate analysis
plt.pie(data.alive.value_counts(),colors=['red','blue'],labels=['yes','no'],autopct='%.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f1147158c40>,
#   <matplotlib.patches.Wedge at 0x7f1147158b80>],
#  [Text(-0.3925749350994583, 1.0275626113924428, 'yes'),
#   Text(0.3925750313068116, -1.0275625746369201, 'no')],
#  [Text(-0.21413178278152267, 0.5604886971231505, '61.62%'),
#   Text(0.21413183525826085, -0.5604886770746836, '38.38%')])

# %%
#bivariate analysis
plt.plot(data['age'],data['pclass'])
plt.xlabel('age')
plt.ylabel('pclass')
# Out:
# Text(0, 0.5, 'pclass')

# %%
#bivariate analysis
plt.scatter(data['age'],data['fare'])
plt.xlabel('age')
plt.ylabel('fare')
# Out:
# Text(0, 0.5, 'fare')

# %%
#bivariate analysis
plt.scatter(data['pclass'],data['fare'])
plt.xlabel('pclass')
plt.ylabel('fare')
# Out:
# Text(0, 0.5, 'fare')

# %%
#bivariate analysis
plt.plot(data['pclass'],data['fare'])
plt.xlabel('pclass')
plt.ylabel('fare')
# Out:
# Text(0, 0.5, 'fare')

# %%
#Multivariate Analysis
pd.plotting.scatter_matrix(data.loc[:, 'age':'fare'], diagonal="kde",figsize=(20,15))
plt.show()

# %%
#multivariate analysis
ax = data[["age","fare"]].plot(figsize=(20,15))
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5));

# %%
#4) Descriptive statistics
data.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
#4) Descriptive statistics
data.var()
# Out:
# <ipython-input-14-f1862db78c41>:2: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.var()
# survived         0.236772
# pclass           0.699015
# age            211.019125
# sibsp            1.216043
# parch            0.649728
# fare          2469.436846
# adult_male       0.239723
# alone            0.239723
# dtype: float64

# %%
#4) Descriptive statistics
data.median()
# Out:
# <ipython-input-15-ee4942ac8d76>:2: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.median()
# survived       0.0000
# pclass         3.0000
# age           28.0000
# sibsp          0.0000
# parch          0.0000
# fare          14.4542
# adult_male     1.0000
# alone          1.0000
# dtype: float64

# %%
#4) Descriptive statistics
data.mode()
# Out:
#    survived  pclass   sex   age  sibsp  parch  fare embarked  class  who  \
# 0         0       3  male  24.0      0      0  8.05        S  Third  man
#
#    adult_male deck  embark_town alive  alone
# 0        True    C  Southampton    no   True

# %%
#5)Handling missing values
data.isnull().any()
# Out:
# survived       False
# pclass         False
# sex            False
# age             True
# sibsp          False
# parch          False
# fare           False
# embarked        True
# class          False
# who            False
# adult_male     False
# deck            True
# embark_town     True
# alive          False
# alone          False
# dtype: bool

# %%
#Handling missing values
data.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
#Handling missing values
data['deck'].fillna(data['deck'].mode(),inplace=True)
data.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       2
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    2
# alive          0
# alone          0
# dtype: int64

# %%
#Handling missing values
data['embark_town'].fillna(data['embark_town'].mode(),inplace=True)
data.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       1
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    1
# alive          0
# alone          0
# dtype: int64

# %%
#6)Finding outliers
data_new = pd.read_csv("titanic.csv")
sns.boxplot(data_new.age)
# Out:
# <Axes: >

# %%
#Finding outliers
perc99=data.age.quantile(0.99)
perc99
# Out:
# 62.0

# %%
#Finding outliers
data_new = pd.read_csv("titanic.csv")
data_new=data_new[data_new.age<=perc99]
sns.boxplot(data.age)
# Out:
# <Axes: >

# %%
#7)Checking for categorical columns
le=LabelEncoder()

# %%
#Checking for categorical columns
data.alive=le.fit_transform(data.alive)

# %%
#Checking for categorical columns
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town  alive  alone
# 0    man        True    C  Southampton      0  False
# 1  woman       False    C    Cherbourg      1  False
# 2  woman       False    C  Southampton      1   True
# 3  woman       False    C  Southampton      1  False
# 4    man        True    C  Southampton      0   True

# %%
#Checking for categorical columns
le=LabelEncoder()

# %%
#Checking for categorical columns
data.sex=le.fit_transform(data.sex)

# %%
#Checking for categorical columns
data.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare embarked  class    who  \
# 0         0       3    1  22.0      1      0   7.2500        S  Third    man
# 1         1       1    0  38.0      1      0  71.2833        C  First  woman
# 2         1       3    0  26.0      0      0   7.9250        S  Third  woman
# 3         1       1    0  35.0      1      0  53.1000        S  First  woman
# 4         0       3    1  35.0      0      0   8.0500        S  Third    man
#
#    adult_male deck  embark_town  alive  alone
# 0        True    C  Southampton      0  False
# 1       False    C    Cherbourg      1  False
# 2       False    C  Southampton      1   True
# 3       False    C  Southampton      1  False
# 4        True    C  Southampton      0   True

# %%
#Checking for categorical columns
le=LabelEncoder()

# %%
#Checking for categorical columns
data.alone=le.fit_transform(data.alone)

# %%
#Checking for categorical columns
data.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare embarked  class    who  \
# 0         0       3    1  22.0      1      0   7.2500        S  Third    man
# 1         1       1    0  38.0      1      0  71.2833        C  First  woman
# 2         1       3    0  26.0      0      0   7.9250        S  Third  woman
# 3         1       1    0  35.0      1      0  53.1000        S  First  woman
# 4         0       3    1  35.0      0      0   8.0500        S  Third    man
#
#    adult_male deck  embark_town  alive  alone
# 0        True    C  Southampton      0      0
# 1       False    C    Cherbourg      1      0
# 2       False    C  Southampton      1      1
# 3       False    C  Southampton      1      0
# 4        True    C  Southampton      0      1

# %%
#8)Splitting data into dependent and independent variables
y=data['survived']

# %%
y.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: survived, dtype: int64

# %%
X=data.drop(columns=['survived'],axis=1)

# %%
X.head()
# Out:
#    pclass  sex   age  sibsp  parch     fare embarked  class    who  \
# 0       3    1  22.0      1      0   7.2500        S  Third    man
# 1       1    0  38.0      1      0  71.2833        C  First  woman
# 2       3    0  26.0      0      0   7.9250        S  Third  woman
# 3       1    0  35.0      1      0  53.1000        S  First  woman
# 4       3    1  35.0      0      0   8.0500        S  Third    man
#
#    adult_male deck  embark_town  alive  alone
# 0        True    C  Southampton      0      0
# 1       False    C    Cherbourg      1      0
# 2       False    C  Southampton      1      1
# 3       False    C  Southampton      1      0
# 4        True    C  Southampton      0      1

# %%
#9)#Scaling independent variables
X=data.drop(columns=['survived','sex','embark_town','deck','class','embarked','who','alive','alone','adult_male'],axis=1)

# %%
#Scaling independent variables
name=X.columns

# %%
name
# Out:
# Index(['pclass', 'age', 'sibsp', 'parch', 'fare'], dtype='object')

# %%
scale=MinMaxScaler()

# %%
X_scaled=scale.fit_transform(X)

# %%
X_scaled
# Out:
# array([[1.        , 0.33415918, 0.2       , 0.        , 0.01415106],
#        [0.        , 0.58191391, 0.2       , 0.        , 0.13913574],
#        [1.        , 0.39609786, 0.        , 0.        , 0.01546857],
#        ...,
#        [0.        , 0.28770517, 0.        , 0.        , 0.0585561 ],
#        [0.        , 0.39609786, 0.        , 0.        , 0.0585561 ],
#        [1.        , 0.48900588, 0.        , 0.        , 0.01512699]])

# %%
X=pd.DataFrame(X_scaled,columns=name)

# %%
X
# Out:
#      pclass       age  sibsp     parch      fare
# 0       1.0  0.334159    0.2  0.000000  0.014151
# 1       0.0  0.581914    0.2  0.000000  0.139136
# 2       1.0  0.396098    0.0  0.000000  0.015469
# 3       0.0  0.535460    0.2  0.000000  0.103644
# 4       1.0  0.535460    0.0  0.000000  0.015713
# ..      ...       ...    ...       ...       ...
# 701     1.0  0.597399    0.0  0.833333  0.056848
# 702     0.5  0.411583    0.0  0.000000  0.025374
# 703     0.0  0.287705    0.0  0.000000  0.058556
# 704     0.0  0.396098    0.0  0.000000  0.058556
# 705     1.0  0.489006    0.0  0.000000  0.015127
#
# [706 rows x 5 columns]

# %%
#10)Splitting the data into training and testing
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
X_train.head()
# Out:
#      pclass       age  sibsp  parch      fare
# 215     1.0  0.380613    0.0    0.0  0.000000
# 577     0.5  0.349644    0.0    0.0  0.025374
# 312     0.0  0.349644    0.2    0.0  0.221098
# 482     1.0  0.396098    0.2    0.0  0.031425
# 651     0.0  0.581914    0.0    0.0  0.000000

# %%
X_test.head()
# Out:
#      pclass       age  sibsp     parch      fare
# 316     0.5  0.705791    0.0  0.000000  0.050749
# 704     0.0  0.396098    0.0  0.000000  0.058556
# 187     0.5  0.674822    0.2  0.000000  0.050749
# 352     1.0  0.380613    0.2  0.000000  0.015176
# 330     0.5  0.519975    0.2  0.166667  0.063436

# %%
y_train
# Out:
# 271    1
# 733    0
# 393    1
# 617    0
# 822    0
#       ..
# 450    0
# 243    0
# 799    0
# 712    1
# 866    1
# Name: survived, Length: 564, dtype: int64

# %%
y_test
# Out:
# 397    0
# 889    1
# 236    0
# 442    0
# 416    1
#       ..
# 610    0
# 207    1
# 378    0
# 20     0
# 446    1
# Name: survived, Length: 142, dtype: int64
